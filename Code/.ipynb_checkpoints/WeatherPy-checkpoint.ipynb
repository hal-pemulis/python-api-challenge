# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import json
import time
import numpy as np
import scipy.stats as st
from pprint import pprint
from config import api_key
from config import gkey
from citipy import citipy
from datetime import datetime

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# # Perform API Calls

# %%
#Perform a weather check on each city using a series of successive API calls.
#Include a print log of each city as it'sbeing processed (with the city number and city name).

latitudes = []
longitudes = []
temp = []
humidity = []
clouds = []
city_list = []
date = []
country = []
wind = []

# Set base URL and other perams
base_url = 'https://api.openweathermap.org/data/2.5/weather?q='
unit = '&units=Imperial'

record = 1
set = 1

# Loop through list of cities
for city in cities:

    # Build query URL
    query_url = base_url + city + unit + '&appid=' + api_key

    # If the URL doesn't exist, it will skip
    try:
    
    # Make request using query URL
        response = requests.get(query_url).json()
        
        # If the info cannot be found, program will skip
        try:
            
            # Navigate json and save weather/city info into lists for each city
            city_list.append(response['name'])
            latitudes.append(response['coord']['lat'])
            longitudes.append(response['coord']['lon'])
            country.append(response['sys']['country'])
            date.append(response['dt'])
            temp.append(response['main']['temp_max'])
            humidity.append(response['main']['humidity'])
            clouds.append(response['clouds']['all'])
            wind.append(response['wind']['speed'])

            print(f"Processing Record {record} of Set {set} | {city}")

        except KeyError:
            print(f"Info not found. Skipping...")

    except KeyError:
        print(f"City {city} not found. Skipping...")

    # When the loop reaches the API limit, the program sleeps and resets    
    record += 1
    if record == 21:
        time.sleep(1)
        record == 0 
        set += 1
# Out:
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | erenhot
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | lasa
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | provideniya
# Processing Record 9 of Set 1 | tarakan
# Processing Record 10 of Set 1 | saint-francois
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | geraldton
# Processing Record 14 of Set 1 | batsfjord
# Processing Record 15 of Set 1 | sitka
# Processing Record 16 of Set 1 | carnarvon
# Info not found. Skipping...
# Processing Record 18 of Set 1 | klaksvik
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | kavieng
# Processing Record 21 of Set 2 | caloundra
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | la ronge
# Processing Record 24 of Set 2 | rantauprapat
# Processing Record 25 of Set 2 | saint-philippe
# Processing Record 26 of Set 2 | ancud
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | alta
# Processing Record 30 of Set 2 | zhengjiatun
# Processing Record 31 of Set 2 | cherskiy
# Processing Record 32 of Set 2 | beloha
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | victoria
# Info not found. Skipping...
# Processing Record 36 of Set 2 | port alfred
# Processing Record 37 of Set 2 | bilma
# Info not found. Skipping...
# Processing Record 39 of Set 2 | cayenne
# Processing Record 40 of Set 2 | kozhva
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | hami
# Processing Record 43 of Set 2 | stabat
# Processing Record 44 of Set 2 | broome
# Processing Record 45 of Set 2 | ushuaia
# Processing Record 46 of Set 2 | kabalo
# Processing Record 47 of Set 2 | clarence town
# Processing Record 48 of Set 2 | ferrol
# Processing Record 49 of Set 2 | healdsburg
# Processing Record 50 of Set 2 | salalah
# Processing Record 51 of Set 2 | alofi
# Processing Record 52 of Set 2 | mantua
# Processing Record 53 of Set 2 | fonte boa
# Processing Record 54 of Set 2 | mar del plata
# Processing Record 55 of Set 2 | whitehorse
# Processing Record 56 of Set 2 | campos
# Info not found. Skipping...
# Processing Record 58 of Set 2 | goundam
# Processing Record 59 of Set 2 | new norfolk
# Processing Record 60 of Set 2 | loiza
# Processing Record 61 of Set 2 | bredasdorp
# Processing Record 62 of Set 2 | nikolskoye
# Processing Record 63 of Set 2 | hithadhoo
# Processing Record 64 of Set 2 | kariba
# Processing Record 65 of Set 2 | waw
# Processing Record 66 of Set 2 | butaritari
# Info not found. Skipping...
# Processing Record 68 of Set 2 | batemans bay
# Processing Record 69 of Set 2 | dikson
# Processing Record 70 of Set 2 | cidreira
# Processing Record 71 of Set 2 | jamestown
# Processing Record 72 of Set 2 | sibi
# Processing Record 73 of Set 2 | torbay
# Processing Record 74 of Set 2 | krasnoselkup
# Processing Record 75 of Set 2 | hilo
# Processing Record 76 of Set 2 | anklam
# Processing Record 77 of Set 2 | cape town
# Processing Record 78 of Set 2 | chakradharpur
# Processing Record 79 of Set 2 | port lincoln
# Processing Record 80 of Set 2 | kudahuvadhoo
# Processing Record 81 of Set 2 | jingdezhen
# Processing Record 82 of Set 2 | atar
# Processing Record 83 of Set 2 | tual
# Processing Record 84 of Set 2 | pangai
# Processing Record 85 of Set 2 | chokurdakh
# Processing Record 86 of Set 2 | vardo
# Info not found. Skipping...
# Processing Record 88 of Set 2 | castro
# Processing Record 89 of Set 2 | antofagasta
# Processing Record 90 of Set 2 | boyolangu
# Processing Record 91 of Set 2 | thinadhoo
# Processing Record 92 of Set 2 | chuy
# Processing Record 93 of Set 2 | buckingham
# Processing Record 94 of Set 2 | kahului
# Processing Record 95 of Set 2 | hermanus
# Processing Record 96 of Set 2 | guerrero negro
# Processing Record 97 of Set 2 | chifeng
# Processing Record 98 of Set 2 | barrow
# Processing Record 99 of Set 2 | nanortalik
# Processing Record 100 of Set 2 | coxim
# Processing Record 101 of Set 2 | faanui
# Processing Record 102 of Set 2 | virginia beach
# Processing Record 103 of Set 2 | kloulklubed
# Processing Record 104 of Set 2 | heerenveen
# Processing Record 105 of Set 2 | kishcha
# Processing Record 106 of Set 2 | kichmengskiy gorodok
# Info not found. Skipping...
# Processing Record 108 of Set 2 | east london
# Processing Record 109 of Set 2 | trapani
# Processing Record 110 of Set 2 | dudinka
# Processing Record 111 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 112 of Set 2 | chicama
# Processing Record 113 of Set 2 | saint anthony
# Processing Record 114 of Set 2 | mwembe
# Info not found. Skipping...
# Processing Record 116 of Set 2 | dongying
# Processing Record 117 of Set 2 | esperance
# Processing Record 118 of Set 2 | vaini
# Processing Record 119 of Set 2 | iqaluit
# Processing Record 120 of Set 2 | bambous virieux
# Processing Record 121 of Set 2 | waingapu
# Info not found. Skipping...
# Processing Record 123 of Set 2 | thompson
# Processing Record 124 of Set 2 | pevek
# Processing Record 125 of Set 2 | champerico
# Processing Record 126 of Set 2 | arraial do cabo
# Processing Record 127 of Set 2 | bayji
# Info not found. Skipping...
# Processing Record 129 of Set 2 | byron bay
# Processing Record 130 of Set 2 | inisa
# Processing Record 131 of Set 2 | trincomalee
# Processing Record 132 of Set 2 | hobart
# Processing Record 133 of Set 2 | georgetown
# Processing Record 134 of Set 2 | komsomolskiy
# Processing Record 135 of Set 2 | urrao
# Processing Record 136 of Set 2 | saint-georges
# Processing Record 137 of Set 2 | qaanaaq
# Processing Record 138 of Set 2 | sekoma
# Processing Record 139 of Set 2 | la rioja
# Processing Record 140 of Set 2 | vestmannaeyjar
# Processing Record 141 of Set 2 | coihaique
# Processing Record 142 of Set 2 | mahebourg
# Processing Record 143 of Set 2 | lumeje
# Info not found. Skipping...
# Processing Record 145 of Set 2 | biak
# Processing Record 146 of Set 2 | gore
# Processing Record 147 of Set 2 | dawei
# Processing Record 148 of Set 2 | bria
# Processing Record 149 of Set 2 | te anau
# Processing Record 150 of Set 2 | port hueneme
# Processing Record 151 of Set 2 | flin flon
# Processing Record 152 of Set 2 | save
# Processing Record 153 of Set 2 | sept-iles
# Info not found. Skipping...
# Processing Record 155 of Set 2 | port elizabeth
# Processing Record 156 of Set 2 | nemuro
# Processing Record 157 of Set 2 | pangnirtung
# Processing Record 158 of Set 2 | khatanga
# Processing Record 159 of Set 2 | bueno brandao
# Info not found. Skipping...
# Processing Record 161 of Set 2 | paralimni
# Processing Record 162 of Set 2 | srinagar
# Processing Record 163 of Set 2 | sur
# Info not found. Skipping...
# Processing Record 165 of Set 2 | andenes
# Processing Record 166 of Set 2 | clyde river
# Info not found. Skipping...
# Processing Record 168 of Set 2 | souillac
# Processing Record 169 of Set 2 | henties bay
# Processing Record 170 of Set 2 | kapaa
# Info not found. Skipping...
# Processing Record 172 of Set 2 | ribeira grande
# Processing Record 173 of Set 2 | kalmunai
# Processing Record 174 of Set 2 | jizan
# Processing Record 175 of Set 2 | tutoia
# Processing Record 176 of Set 2 | macusani
# Processing Record 177 of Set 2 | kavarna
# Processing Record 178 of Set 2 | richards bay
# Processing Record 179 of Set 2 | nantucket
# Processing Record 180 of Set 2 | adrar
# Processing Record 181 of Set 2 | saint george
# Processing Record 182 of Set 2 | havre-saint-pierre
# Info not found. Skipping...
# Processing Record 184 of Set 2 | ulladulla
# Info not found. Skipping...
# Info not found. Skipping...
# Processing Record 187 of Set 2 | svetlyy
# Processing Record 188 of Set 2 | broken hill
# Processing Record 189 of Set 2 | klyuchi
# Processing Record 190 of Set 2 | furano
# Processing Record 191 of Set 2 | hurghada
# Processing Record 192 of Set 2 | bathsheba
# Processing Record 193 of Set 2 | tiznit
# Info not found. Skipping...
# Processing Record 195 of Set 2 | pachino
# Processing Record 196 of Set 2 | buala
# Processing Record 197 of Set 2 | korla
# Processing Record 198 of Set 2 | saiha
# Processing Record 199 of Set 2 | itarema
# Info not found. Skipping...
# Processing Record 201 of Set 2 | avarua
# Processing Record 202 of Set 2 | hay river
# Processing Record 203 of Set 2 | kulhudhuffushi
# Processing Record 204 of Set 2 | maragogi
# Info not found. Skipping...
# Processing Record 206 of Set 2 | arman
# Processing Record 207 of Set 2 | kurilsk
# Processing Record 208 of Set 2 | kaitangata
# Processing Record 209 of Set 2 | sola
# Processing Record 210 of Set 2 | saint-augustin
# Info not found. Skipping...
# Processing Record 212 of Set 2 | avera
# Processing Record 213 of Set 2 | hasaki
# Processing Record 214 of Set 2 | cap malheureux
# Processing Record 215 of Set 2 | at-bashi
# Processing Record 216 of Set 2 | hofn
# Processing Record 217 of Set 2 | kaeo
# Processing Record 218 of Set 2 | mecca
# Processing Record 219 of Set 2 | mabaruma
# Processing Record 220 of Set 2 | road town
# Processing Record 221 of Set 2 | abu samrah
# Processing Record 222 of Set 2 | yumen
# Processing Record 223 of Set 2 | heilbad heiligenstadt
# Info not found. Skipping...
# Processing Record 225 of Set 2 | umm lajj
# Processing Record 226 of Set 2 | sampit
# Processing Record 227 of Set 2 | dunedin
# Info not found. Skipping...
# Processing Record 229 of Set 2 | coahuayana
# Processing Record 230 of Set 2 | kenmare
# Processing Record 231 of Set 2 | muana
# Processing Record 232 of Set 2 | vengurla
# Processing Record 233 of Set 2 | namatanai
# Processing Record 234 of Set 2 | alyangula
# Processing Record 235 of Set 2 | pisco
# Processing Record 236 of Set 2 | yairipok
# Processing Record 237 of Set 2 | hobyo
# Processing Record 238 of Set 2 | sardarshahr
# Processing Record 239 of Set 2 | upernavik
# Processing Record 240 of Set 2 | patos de minas
# Processing Record 241 of Set 2 | bengkulu
# Processing Record 242 of Set 2 | dingle
# Processing Record 243 of Set 2 | lebu
# Processing Record 244 of Set 2 | sao filipe
# Processing Record 245 of Set 2 | severo-kurilsk
# Info not found. Skipping...
# Processing Record 247 of Set 2 | gummidipundi
# Processing Record 248 of Set 2 | pastrana
# Processing Record 249 of Set 2 | tuktoyaktuk
# Processing Record 250 of Set 2 | necochea
# Processing Record 251 of Set 2 | lulea
# Processing Record 252 of Set 2 | fortuna
# Processing Record 253 of Set 2 | san cristobal
# Processing Record 254 of Set 2 | naze
# Processing Record 255 of Set 2 | maniitsoq
# Processing Record 256 of Set 2 | kruisfontein
# Processing Record 257 of Set 2 | sheridan
# Processing Record 258 of Set 2 | sapernoye
# Processing Record 259 of Set 2 | boende
# Processing Record 260 of Set 2 | ostrovnoy
# Processing Record 261 of Set 2 | dukat
# Info not found. Skipping...
# Processing Record 263 of Set 2 | coquimbo
# Processing Record 264 of Set 2 | portland
# Processing Record 265 of Set 2 | saskylakh
# Processing Record 266 of Set 2 | port macquarie
# Processing Record 267 of Set 2 | hastings
# Processing Record 268 of Set 2 | zhezkazgan
# Processing Record 269 of Set 2 | saldanha
# Processing Record 270 of Set 2 | mitsamiouli
# Processing Record 271 of Set 2 | ouallam
# Processing Record 272 of Set 2 | college
# Info not found. Skipping...
# Processing Record 274 of Set 2 | nouadhibou
# Processing Record 275 of Set 2 | sechura
# Processing Record 276 of Set 2 | kindu
# Processing Record 277 of Set 2 | mikhaylovskoye
# Processing Record 278 of Set 2 | lillooet
# Processing Record 279 of Set 2 | suntar
# Processing Record 280 of Set 2 | norman wells
# Processing Record 281 of Set 2 | boden
# Processing Record 282 of Set 2 | codrington
# Processing Record 283 of Set 2 | padang
# Processing Record 284 of Set 2 | qingyuan
# Processing Record 285 of Set 2 | khislavichi
# Info not found. Skipping...
# Info not found. Skipping...
# Processing Record 288 of Set 2 | juneau
# Processing Record 289 of Set 2 | san patricio
# Processing Record 290 of Set 2 | boguchany
# Processing Record 291 of Set 2 | nome
# Processing Record 292 of Set 2 | caravelas
# Processing Record 293 of Set 2 | vao
# Processing Record 294 of Set 2 | evans
# Processing Record 295 of Set 2 | shingu
# Processing Record 296 of Set 2 | iskateley
# Processing Record 297 of Set 2 | edgewater
# Processing Record 298 of Set 2 | lorengau
# Processing Record 299 of Set 2 | cacimba de dentro
# Processing Record 300 of Set 2 | turukhansk
# Processing Record 301 of Set 2 | ust-kuyga
# Processing Record 302 of Set 2 | lavrentiya
# Processing Record 303 of Set 2 | inhambane
# Processing Record 304 of Set 2 | constitucion
# Processing Record 305 of Set 2 | harper
# Processing Record 306 of Set 2 | narsaq
# Processing Record 307 of Set 2 | pemangkat
# Processing Record 308 of Set 2 | minab
# Info not found. Skipping...
# Processing Record 310 of Set 2 | bereda
# Processing Record 311 of Set 2 | cabo san lucas
# Processing Record 312 of Set 2 | sumenep
# Processing Record 313 of Set 2 | otane
# Processing Record 314 of Set 2 | manaia
# Processing Record 315 of Set 2 | hobbs
# Processing Record 316 of Set 2 | tsabong
# Processing Record 317 of Set 2 | moyale
# Processing Record 318 of Set 2 | salekhard
# Processing Record 319 of Set 2 | zeya
# Processing Record 320 of Set 2 | mana
# Processing Record 321 of Set 2 | zhizdra
# Info not found. Skipping...
# Processing Record 323 of Set 2 | pasni
# Processing Record 324 of Set 2 | hambantota
# Processing Record 325 of Set 2 | oktyabrskoye
# Processing Record 326 of Set 2 | faya
# Processing Record 327 of Set 2 | silva jardim
# Processing Record 328 of Set 2 | aykhal
# Processing Record 329 of Set 2 | bac lieu
# Processing Record 330 of Set 2 | ushtobe
# Processing Record 331 of Set 2 | balkanabat
# Processing Record 332 of Set 2 | niquelandia
# Processing Record 333 of Set 2 | kodiak
# Processing Record 334 of Set 2 | saint-pierre
# Processing Record 335 of Set 2 | lata
# Processing Record 336 of Set 2 | novobelokatay
# Info not found. Skipping...
# Processing Record 338 of Set 2 | kavaratti
# Info not found. Skipping...
# Processing Record 340 of Set 2 | ciney
# Processing Record 341 of Set 2 | cuenca
# Processing Record 342 of Set 2 | urucara
# Processing Record 343 of Set 2 | ugoofaaru
# Processing Record 344 of Set 2 | yerbogachen
# Processing Record 345 of Set 2 | logrono
# Processing Record 346 of Set 2 | aksu
# Processing Record 347 of Set 2 | ivanava
# Processing Record 348 of Set 2 | huarmey
# Processing Record 349 of Set 2 | ardesen
# Processing Record 350 of Set 2 | nabire
# Processing Record 351 of Set 2 | najran
# Processing Record 352 of Set 2 | channel-port aux basques
# Processing Record 353 of Set 2 | ilulissat
# Processing Record 354 of Set 2 | shagonar
# Processing Record 355 of Set 2 | kunya
# Processing Record 356 of Set 2 | vostok
# Info not found. Skipping...
# Processing Record 358 of Set 2 | savannah bight
# Processing Record 359 of Set 2 | san quintin
# Processing Record 360 of Set 2 | alice springs
# Processing Record 361 of Set 2 | pundaguitan
# Processing Record 362 of Set 2 | belyy yar
# Processing Record 363 of Set 2 | sao jose da coroa grande
# Processing Record 364 of Set 2 | la asuncion
# Processing Record 365 of Set 2 | antalaha
# Processing Record 366 of Set 2 | anadyr
# Processing Record 367 of Set 2 | campo de criptana
# Processing Record 368 of Set 2 | samarai
# Info not found. Skipping...
# Processing Record 370 of Set 2 | lensk
# Processing Record 371 of Set 2 | aklavik
# Processing Record 372 of Set 2 | lagoa
# Processing Record 373 of Set 2 | porkhov
# Processing Record 374 of Set 2 | magadan
# Processing Record 375 of Set 2 | fujin
# Processing Record 376 of Set 2 | camapua
# Processing Record 377 of Set 2 | aswan
# Processing Record 378 of Set 2 | egvekinot
# Processing Record 379 of Set 2 | gushikawa
# Processing Record 380 of Set 2 | van
# Info not found. Skipping...
# Info not found. Skipping...
# Processing Record 383 of Set 2 | port augusta
# Processing Record 384 of Set 2 | pimentel
# Processing Record 385 of Set 2 | port hedland
# Processing Record 386 of Set 2 | andros town
# Processing Record 387 of Set 2 | alexandria
# Processing Record 388 of Set 2 | ponta do sol
# Processing Record 389 of Set 2 | huaiyuan
# Processing Record 390 of Set 2 | asosa
# Processing Record 391 of Set 2 | burns lake
# Processing Record 392 of Set 2 | iquitos
# Processing Record 393 of Set 2 | boissevain
# Processing Record 394 of Set 2 | iroquois falls
# Processing Record 395 of Set 2 | fort abbas
# Processing Record 396 of Set 2 | novikovo
# Processing Record 397 of Set 2 | mount isa
# Processing Record 398 of Set 2 | tay ninh
# Processing Record 399 of Set 2 | ambilobe
# Processing Record 400 of Set 2 | epiniana
# Processing Record 401 of Set 2 | ondangwa
# Processing Record 402 of Set 2 | monticello
# Processing Record 403 of Set 2 | pop
# Processing Record 404 of Set 2 | vila franca do campo
# Processing Record 405 of Set 2 | flinders
# Info not found. Skipping...
# Processing Record 407 of Set 2 | ixtapa
# Processing Record 408 of Set 2 | fort stewart
# Processing Record 409 of Set 2 | latung
# Processing Record 410 of Set 2 | mbini
# Processing Record 411 of Set 2 | poum
# Processing Record 412 of Set 2 | saurimo
# Processing Record 413 of Set 2 | los llanos de aridane
# Processing Record 414 of Set 2 | sao miguel do araguaia
# Processing Record 415 of Set 2 | anchorage
# Processing Record 416 of Set 2 | port shepstone
# Processing Record 417 of Set 2 | berlevag
# Processing Record 418 of Set 2 | boddam
# Processing Record 419 of Set 2 | tazovskiy
# Processing Record 420 of Set 2 | tuatapere
# Processing Record 421 of Set 2 | dandong
# Processing Record 422 of Set 2 | santiago del estero
# Processing Record 423 of Set 2 | new plymouth
# Processing Record 424 of Set 2 | yulara
# Processing Record 425 of Set 2 | leningradskiy
# Processing Record 426 of Set 2 | san-pedro
# Processing Record 427 of Set 2 | gemena
# Processing Record 428 of Set 2 | barentu
# Processing Record 429 of Set 2 | katherine
# Processing Record 430 of Set 2 | meadow lake
# Processing Record 431 of Set 2 | newport
# Processing Record 432 of Set 2 | camacha
# Processing Record 433 of Set 2 | aanekoski
# Processing Record 434 of Set 2 | poso
# Processing Record 435 of Set 2 | wajima
# Processing Record 436 of Set 2 | zanjan
# Processing Record 437 of Set 2 | bosobolo
# Processing Record 438 of Set 2 | laguna
# Processing Record 439 of Set 2 | seydi
# Processing Record 440 of Set 2 | fare
# Processing Record 441 of Set 2 | taoudenni
# Processing Record 442 of Set 2 | axim
# Processing Record 443 of Set 2 | bharatpur
# Processing Record 444 of Set 2 | mareeba
# Processing Record 445 of Set 2 | maracacume
# Processing Record 446 of Set 2 | olivenza
# Processing Record 447 of Set 2 | mount gambier
# Processing Record 448 of Set 2 | glenwood springs
# Processing Record 449 of Set 2 | rawson
# Processing Record 450 of Set 2 | malindi
# Processing Record 451 of Set 2 | belaya gora
# Processing Record 452 of Set 2 | druzhba
# Processing Record 453 of Set 2 | lazaro cardenas
# Processing Record 454 of Set 2 | katsuura
# Info not found. Skipping...
# Processing Record 456 of Set 2 | hirara
# Processing Record 457 of Set 2 | tukrah
# Info not found. Skipping...
# Processing Record 459 of Set 2 | ampanihy
# Processing Record 460 of Set 2 | zhuhai
# Processing Record 461 of Set 2 | chesterton
# Info not found. Skipping...
# Processing Record 463 of Set 2 | olginskaya
# Processing Record 464 of Set 2 | ploemeur
# Processing Record 465 of Set 2 | schwechat
# Info not found. Skipping...
# Processing Record 467 of Set 2 | kenora
# Processing Record 468 of Set 2 | idritsa
# Processing Record 469 of Set 2 | sovetskiy
# Processing Record 470 of Set 2 | ahipara
# Processing Record 471 of Set 2 | karaton
# Processing Record 472 of Set 2 | soyaux
# Processing Record 473 of Set 2 | moron
# Processing Record 474 of Set 2 | wharton
# Processing Record 475 of Set 2 | fairbanks
# Processing Record 476 of Set 2 | sisimiut
# Processing Record 477 of Set 2 | sheopur
# Processing Record 478 of Set 2 | sterling
# Processing Record 479 of Set 2 | bandar
# Processing Record 480 of Set 2 | ouricuri
# Processing Record 481 of Set 2 | bridlington
# Processing Record 482 of Set 2 | chimoio
# Processing Record 483 of Set 2 | grenada
# Processing Record 484 of Set 2 | ayan
# Processing Record 485 of Set 2 | airai
# Processing Record 486 of Set 2 | turbat
# Processing Record 487 of Set 2 | port hardy
# Processing Record 488 of Set 2 | benguela
# Processing Record 489 of Set 2 | nioro
# Processing Record 490 of Set 2 | sao geraldo do araguaia
# Processing Record 491 of Set 2 | nunkini
# Processing Record 492 of Set 2 | lisakovsk
# Processing Record 493 of Set 2 | saquena
# Processing Record 494 of Set 2 | veraval
# Processing Record 495 of Set 2 | pangkalanbuun
# Processing Record 496 of Set 2 | puerto escondido
# Info not found. Skipping...
# Processing Record 498 of Set 2 | ishigaki
# Processing Record 499 of Set 2 | candia
# Processing Record 500 of Set 2 | inverness
# Processing Record 501 of Set 2 | san rafael del sur
# Processing Record 502 of Set 2 | doha
# Processing Record 503 of Set 2 | aksarka
# Processing Record 504 of Set 2 | lake havasu city
# Processing Record 505 of Set 2 | severo-yeniseyskiy
# Processing Record 506 of Set 2 | lompoc
# Processing Record 507 of Set 2 | zyryanka
# Info not found. Skipping...
# Processing Record 509 of Set 2 | mandiana
# Processing Record 510 of Set 2 | tucuman
# Processing Record 511 of Set 2 | navahrudak
# Processing Record 512 of Set 2 | ballina
# Processing Record 513 of Set 2 | husavik
# Processing Record 514 of Set 2 | primo tapia
# Info not found. Skipping...
# Processing Record 516 of Set 2 | lander
# Processing Record 517 of Set 2 | homer
# Processing Record 518 of Set 2 | vila velha
# Processing Record 519 of Set 2 | vestmanna
# Processing Record 520 of Set 2 | pauini
# Processing Record 521 of Set 2 | barra
# Processing Record 522 of Set 2 | blythe
# Processing Record 523 of Set 2 | veracruz
# Processing Record 524 of Set 2 | evensk
# Processing Record 525 of Set 2 | wanning
# Processing Record 526 of Set 2 | beyneu
# Processing Record 527 of Set 2 | pak phanang
# Info not found. Skipping...
# Info not found. Skipping...
# Processing Record 530 of Set 2 | raudeberg
# Processing Record 531 of Set 2 | hokitika
# Processing Record 532 of Set 2 | isangel
# Processing Record 533 of Set 2 | araceli
# Processing Record 534 of Set 2 | qaqortoq
# Info not found. Skipping...
# Info not found. Skipping...
# Processing Record 537 of Set 2 | abalak
# Processing Record 538 of Set 2 | yavatmal
# Processing Record 539 of Set 2 | san jeronimo
# Processing Record 540 of Set 2 | margate
# Processing Record 541 of Set 2 | tessalit
# Info not found. Skipping...
# Processing Record 543 of Set 2 | ipameri
# Processing Record 544 of Set 2 | hargeysa
# Processing Record 545 of Set 2 | irtyshskiy
# Processing Record 546 of Set 2 | durban
# Processing Record 547 of Set 2 | sorland
# Processing Record 548 of Set 2 | rudnogorsk
# Processing Record 549 of Set 2 | tura
# Processing Record 550 of Set 2 | grand gaube
# Processing Record 551 of Set 2 | maldonado
# Info not found. Skipping...
# Processing Record 553 of Set 2 | chalmette
# Processing Record 554 of Set 2 | muros
# Processing Record 555 of Set 2 | tingi
# Processing Record 556 of Set 2 | beroroha
# Processing Record 557 of Set 2 | gogrial
# Processing Record 558 of Set 2 | savelugu
# Processing Record 559 of Set 2 | hovd
# Processing Record 560 of Set 2 | pacific grove
# Processing Record 561 of Set 2 | shakawe
# Processing Record 562 of Set 2 | sitrah
# Info not found. Skipping...
# Processing Record 564 of Set 2 | monopoli
# Processing Record 565 of Set 2 | viedma
# Processing Record 566 of Set 2 | vermilion
# Processing Record 567 of Set 2 | yuzhno-sukhokumsk
# Processing Record 568 of Set 2 | san felipe
# Processing Record 569 of Set 2 | sinnamary
# Processing Record 570 of Set 2 | taltal
# Processing Record 571 of Set 2 | grand-santi
# Processing Record 572 of Set 2 | samana
# Processing Record 573 of Set 2 | namibe
# Processing Record 574 of Set 2 | mnogovershinnyy
# Processing Record 575 of Set 2 | esil
# Processing Record 576 of Set 2 | touros
# Info not found. Skipping...
# Processing Record 578 of Set 2 | patur
# Processing Record 579 of Set 2 | omboue
# Processing Record 580 of Set 2 | jacareacanga
# Processing Record 581 of Set 2 | comodoro rivadavia
# Processing Record 582 of Set 2 | ambunti
# Processing Record 583 of Set 2 | beringovskiy
# Processing Record 584 of Set 2 | coromandel
# Processing Record 585 of Set 2 | de-kastri
# Processing Record 586 of Set 2 | kalakamati
# Processing Record 587 of Set 2 | sao joao da barra
# Processing Record 588 of Set 2 | pombas
# Processing Record 589 of Set 2 | noumea
# Processing Record 590 of Set 2 | huilong
# Info not found. Skipping...
# Info not found. Skipping...
# Processing Record 593 of Set 2 | odda
# Processing Record 594 of Set 2 | rincon
# Processing Record 595 of Set 2 | santa isabel do rio negro
# Processing Record 596 of Set 2 | changli
# Processing Record 597 of Set 2 | batticaloa
# Processing Record 598 of Set 2 | melbu
# Info not found. Skipping...
# Processing Record 600 of Set 2 | dharchula
# Processing Record 601 of Set 2 | ximei
# Processing Record 602 of Set 2 | zinder
# Processing Record 603 of Set 2 | takaka
# Processing Record 604 of Set 2 | dourados
# Processing Record 605 of Set 2 | chipata
# Processing Record 606 of Set 2 | honiara
# Processing Record 607 of Set 2 | tsagan aman
# Info not found. Skipping...
# Processing Record 609 of Set 2 | biltine
# Processing Record 610 of Set 2 | cartagena
# Processing Record 611 of Set 2 | hurricane
# Processing Record 612 of Set 2 | luderitz
# Processing Record 613 of Set 2 | scarborough
# Processing Record 614 of Set 2 | vila do maio
# Processing Record 615 of Set 2 | enshi
# Processing Record 616 of Set 2 | rapid valley
# Info not found. Skipping...
# Processing Record 618 of Set 2 | tucupita
# Processing Record 619 of Set 2 | omsukchan

# %%
data = {'City' : city_list, 'Country' : country, 
        'Lat' : latitudes, 'Lng' : longitudes,
        'Max Temp' : temp, 'Humidity' : humidity, 
        'Cloudiness' : clouds, 'Wind Speed' : wind}

weather_df = pd.DataFrame(data)

weather_df.to_csv('../Output_Data/Weather_Data.csv')

weather_df.head()
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.65  115.33     61.00        90          80
# 1       Erenhot      CN  43.65  111.98     25.29        54         100
# 2       Rikitea      PF -23.12 -134.97     77.45        82           1
# 3  Puerto Ayora      EC  -0.74  -90.35     86.00        70          20
# 4          Laas      IT  46.62   10.70     48.20        86           0
#
#    Wind Speed
# 0       13.22
# 1       13.65
# 2       15.61
# 3        9.17
# 4        3.36

# %%
plt.scatter(latitudes, temp)
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title('Temperature by Latitude')
plt.grid(True)
plt.savefig('../Output_Data/lat_temp.png')

# %%
plt.scatter(latitudes, humidity)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Humidity by Latitude')
plt.grid(True)
plt.savefig('../Output_Data/lat_humidity.png')

# %%
plt.scatter(latitudes, clouds)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Cloudiness by Latitude')
plt.grid(True)
plt.savefig('../Output_Data/lat_cloud.png')

# %%
plt.scatter(latitudes, wind)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.title('Wind Speed by Latitude')
plt.grid(True)
plt.savefig('../Output_Data/wind.png')

# %% [markdown]
# # Linear Regression
#
# Create Northern and Southern Hemisphere DataFrames

# %%
# A function to create linear regression plots
def regress(x, y, hemisphere):
    hem = []
    i = []
    
    # Checks for hemisphere argument ('n' or 's')
    if hemisphere == 'n':
        
        # For every latitude, check if greater than or equal to 0
        for lat in x:
            if lat >= 0:
                
                # Adds values to lists if meets requirement
                hem.append(lat)
                i.append(y[x.index(lat)]) 
                
        coords = (0,10)
    
    # Same, but for the Southern Hemisphere
    if hemisphere == 's':
        for lat in x:
            if lat <= 0:
                hem.append(lat)
                i.append(y[x.index(lat)])

        coords = (-50,20)

                
    # Calculates linear regression
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(hem,i)
    hem = np.asarray(hem, dtype=np.float64)
    regress_values = hem * slope + intercept

    # Plots scatter plot and regresion
    plt.scatter(hem,i)
    plt.plot(hem,regress_values,"r-")

    # Annotates graph with equation
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.annotate(line_eq,xy=coords,fontsize=15,color="red")
    plt.xlabel('Latitude')
    
    # Prints r squared value from linregress function
    print(f'The r-squared is: {rvalue}')

# %%
regress(latitudes,temp,'n')
plt.ylabel('Temp (F)')
plt.title('Temp in the Northern Hemisphere')
# Out:
# The r-squared is: -0.8698062626061999
# Text(0.5, 1.0, 'Temp in the Northern Hemisphere')

# %%
regress(latitudes,temp,'s')
plt.ylim(20,110)
plt.ylabel('Temp (F)')
plt.title('Temp in the Southern Hemisphere')
# Out:
# The r-squared is: 0.5823234214412684
# Text(0.5, 1.0, 'Temp in the Southern Hemisphere')

# %%
regress(latitudes, humidity, 'n')
plt.ylabel('Humidity (%)')
plt.title('Humidity in the Northern Hemisphere')
# Out:
# The r-squared is: 0.3380235553491084
# Text(0.5, 1.0, 'Humidity in the Northern Hemisphere')

# %%
regress(latitudes, humidity, 's')
plt.ylabel('Humidity (%)')
plt.title('Humidity in the Southern Hemisphere')
# Out:
# The r-squared is: 0.15036290380192813
# Text(0.5, 1.0, 'Humidity in the Southern Hemisphere')

# %%
regress(latitudes, clouds , 'n')
plt.ylabel('Cloudiness (%)')
plt.title('Clouldines in the Northern Hemisphere')
# Out:
# The r-squared is: 0.2049355940357428
# Text(0.5, 1.0, 'Clouldines in the Northern Hemisphere')

# %%
regress(latitudes, clouds , 's')
plt.ylabel('Cloudiness (%)')
plt.title('Cloudiness in the Southern Hemisphere')
# Out:
# The r-squared is: 0.16409544343039265
# Text(0.5, 1.0, 'Cloudiness in the Southern Hemisphere')

# %%
regress(latitudes, wind ,'n')
plt.ylabel('Wind Speed (MPH)')
plt.title('Wind speed in the Northern Hemisphere')
# Out:
# The r-squared is: 0.20328861639354404
# Text(0.5, 1.0, 'Wind speed in the Northern Hemisphere')

# %%
regress(latitudes, wind ,'s')
plt.ylabel('Wind Speed (MPH)')
plt.title('Wind speed in the Southern Hemisphere')
# Out:
# The r-squared is: -0.20676010970617625
# Text(0.5, 1.0, 'Wind speed in the Southern Hemisphere')
