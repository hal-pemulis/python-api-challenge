# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import json
import time
import numpy as np
import scipy.stats as st
from pprint import pprint
from config import api_key
from config import gkey
from citipy import citipy
from datetime import datetime

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %% [markdown]
# # Perform API Calls
# #Perform a weather check on each city using a series of successive API calls.
# #Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
latitudes = []
longitudes = []
temp = []
humidity = []
clouds = []
city_list = []
date = []
country = []
wind = []

# Set base URL and other perams
base_url = 'https://api.openweathermap.org/data/2.5/weather?q='
unit = '&units=Imperial'

record = 1
set = 1

# Loop through list of cities
for city in cities:

    # Build query URL
    query_url = base_url + city + unit + '&appid=' + api_key

    # If the URL doesn't exist, it will skip
    try:
    
    # Make request using query URL
        response = requests.get(query_url).json()
        
        # If the info cannot be found, program will skip
        try:
            
            # Navigate json and save weather/city info into lists for each city
            city_list.append(response['name'])
            latitudes.append(response['coord']['lat'])
            longitudes.append(response['coord']['lat'])
            country.append(response['sys']['country'])
            date.append(response['dt'])
            temp.append(response['main']['temp_max'])
            humidity.append(response['main']['humidity'])
            clouds.append(response['clouds']['all'])
            wind.append(response['wind']['speed'])

            print(f"Processing Record {record} of Set {set} | {city}")

        except KeyError:
            print(f"Info not found. Skipping...")

    except KeyError:
        print(f"City {city} not found. Skipping...")

    # When the loop reaches the API limit, the program sleeps and resets    
    record += 1
    if record == 21:
        time.sleep(1)
        record == 0 
        set += 1
# Out:
# Processing Record 0 of Set 2 | qaanaaq
# Processing Record 1 of Set 2 | ushuaia
# Processing Record 2 of Set 2 | havre-saint-pierre
# Processing Record 3 of Set 2 | mar del plata
# Info not found. Skipping...
# Processing Record 5 of Set 2 | castro
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | qinzhou
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | tuktoyaktuk
# Processing Record 12 of Set 2 | port lincoln
# Processing Record 13 of Set 2 | tipuani
# Processing Record 14 of Set 2 | tateyama
# Processing Record 15 of Set 2 | pokhara
# Processing Record 16 of Set 2 | lompoc
# Processing Record 17 of Set 2 | flinders
# Info not found. Skipping...
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | hasaki
# Info not found. Skipping...
# Processing Record 22 of Set 2 | keffi
# Processing Record 23 of Set 2 | zhifang
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | cidreira
# Processing Record 26 of Set 2 | albany
# Processing Record 27 of Set 2 | manokwari
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | jamestown
# Processing Record 31 of Set 2 | jacareacanga
# Processing Record 32 of Set 2 | kruisfontein
# Processing Record 33 of Set 2 | rikitea
# Processing Record 34 of Set 2 | victoria
# Processing Record 35 of Set 2 | upernavik
# Processing Record 36 of Set 2 | ambilobe
# Processing Record 37 of Set 2 | bethel
# Processing Record 38 of Set 2 | codrington
# Info not found. Skipping...
# Processing Record 40 of Set 2 | atar
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | foumban
# Processing Record 43 of Set 2 | narsaq
# Processing Record 44 of Set 2 | dingle
# Processing Record 45 of Set 2 | bengkulu
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | orlik
# Info not found. Skipping...
# Processing Record 49 of Set 2 | ponezhukay
# Processing Record 50 of Set 2 | los llanos de aridane
# Processing Record 51 of Set 2 | bac ninh
# Processing Record 52 of Set 2 | camana
# Info not found. Skipping...
# Processing Record 54 of Set 2 | guerrero negro
# Processing Record 55 of Set 2 | roma
# Processing Record 56 of Set 2 | namtsy
# Processing Record 57 of Set 2 | axim
# Processing Record 58 of Set 2 | sahuaripa
# Processing Record 59 of Set 2 | faanui
# Processing Record 60 of Set 2 | hermanus
# Processing Record 61 of Set 2 | berezovyy
# Processing Record 62 of Set 2 | bredasdorp
# Processing Record 63 of Set 2 | geraldton
# Processing Record 64 of Set 2 | port alfred
# Processing Record 65 of Set 2 | nikolskoye
# Processing Record 66 of Set 2 | severo-kurilsk
# Processing Record 67 of Set 2 | yellowknife
# Processing Record 68 of Set 2 | kapaa
# Processing Record 69 of Set 2 | chuy
# Processing Record 70 of Set 2 | klaksvik
# Processing Record 71 of Set 2 | saint george
# Processing Record 72 of Set 2 | north myrtle beach
# Info not found. Skipping...
# Processing Record 74 of Set 2 | mataura
# Processing Record 75 of Set 2 | sitka
# Info not found. Skipping...
# Processing Record 77 of Set 2 | taloda
# Processing Record 78 of Set 2 | henties bay
# Processing Record 79 of Set 2 | iqaluit
# Processing Record 80 of Set 2 | lukovetskiy
# Processing Record 81 of Set 2 | acarau
# Processing Record 82 of Set 2 | sao joao da barra
# Processing Record 83 of Set 2 | busselton
# Processing Record 84 of Set 2 | san jose
# Processing Record 85 of Set 2 | broken hill
# Processing Record 86 of Set 2 | kodiak
# Info not found. Skipping...
# Info not found. Skipping...
# Processing Record
# Info not found. Skipping...
# Processing Record 244 of Set 2 | coronado
# Processing Record 245 of Set 2 | sao felix do xingu
# Processing Record 246 of Set 2 | san pedro
# Processing Record 247 of Set 2 | puerto ayora
# Processing Record 248 of Set 2 | san joaquin
# Processing Record 249 of Set 2 | dongsheng
# Processing Record 250 of Set 2 | konstantinovskiy
# Processing Record 251 of Set 2 | mitchell
# Processing Record 252 of Set 2 | sabang
# Processing Record 253 of Set 2 | zhuhai
# Processing Record 254 of Set 2 | sukhobezvodnoye
# Processing Record 255 of Set 2 | noumea
# Processing Record 256 of Set 2 | mao
# Processing Record 257 of Set 2 | vila
# Processing Record 258 of Set 2 | burgeo
# Processing Record 259 of Set 2 | ocean city
# Processing Record 260 of Set 2 | bilibino
# Info not found. Skipping...
# Processing Record 262 of Set 2 | saint-philippe
# Processing Record 263 of Set 2 | hofn
# Processing Record 264 of Set 2 | yenagoa
# Processing Record 265 of Set 2 | la ronge
# Info not found. Skipping...
# Processing Record 267 of Set 2 | xai-xai
# Processing Record 268 of Set 2 | broadford
# Processing Record 269 of Set 2 | san roque
# Processing Record 270 of Set 2 | port hawkesbury
# Processing Record 271 of Set 2 | taoudenni
# Processing Record 272 of Set 2 | ilulissat
# Processing Record 273 of Set 2 | aksu
# Processing Record 274 of Set 2 | cesenatico
# Processing Record 275 of Set 2 | mareeba
# Processing Record 276 of Set 2 | ancud
# Processing Record 277 of Set 2 | tagajo
# Processing Record 278 of Set 2 | inta
# Processing Record 279 of Set 2 | talnakh
# Processing Record 280 of Set 2 | tuatapere
# Processing Record 281 of Set 2 | kulhudhuffushi
# Processing Record 282 of Set 2 | yumen
# Processing Record 283 of Set 2 | jalu
# Processing Record 284 of Set 2 | springbok
# Processing Record 285 of Set 2 | port hardy
# Processing Record 286 of Set 2 | teya
# Processing Record 287 of Set 2 | saldanha
# Processing Record 288 of Set 2 | cerignola
# Processing Record 289 of Set 2 | saint-joseph
# Processing Record 290 of Set 2 | san cristobal
# Processing Record 291 of Set 2 | dabat
# Processing Record 292 of Set 2 | sawakin
# Processing Record 293 of Set 2 | takhtamygda
# Processing Record 294 of Set 2 | senador jose porfirio
# Info not found. Skipping...
# Info not found. Skipping...
# Processing Record 297 of Set 2 | amuntai
# Processing Record 298 of Set 2 | wanning
# Processing Record 299 of Set 2 | porto torres
# Processing Record 300 of Set 2 | sembe
# Processing Record 301 of Set 2 | meulaboh
# Processing Record 302 of Set 2 | xihe
# Processing Record 303 of Set 2 | jumla
# Processing Record 304 of Set 2 | salta
# Processing Record 305 of Set 2 | kaitangata
# Processing Record 306 of Set 2 | rawson
# Processing Record 307 of Set 2 | mount isa
# Info not found. Skipping...
# Processing Record 309 of Set 2 | kayerkan
# Processing Record 310 of Set 2 | plettenberg bay
# Processing Record 311 of Set 2 | carlsbad
# Processing Record 312 of Set 2 | clyde river
# Processing Record 313 of Set 2 | tasiilaq
# Processing Record 314 of Set 2 | tabuk
# Processing Record 315 of Set 2 | pitimbu
# Processing Record 316 of Set 2 | whitehorse
# Processing Record 317 of Set 2 | esperance
# Processing Record 318 of Set 2 | panguna
# Processing Record 319 of Set 2 | conde
# Processing Record 320 of Set 2 | canberra
# Processing Record 321 of Set 2 | athabasca
# Processing Record 401 of Set 2 | shitanjing
# Processing Record 402 of Set 2 | el playon
# Processing Record 403 of Set 2 | ostersund
# Processing Record 404 of Set 2 | tucuman
# Info not found. Skipping...
# Processing Record 406 of Set 2 | tezu
# Processing Record 407 of Set 2 | leshukonskoye
# Processing Record 408 of Set 2 | khorol
# Processing Record 409 of Set 2 | fukue
# Processing Record 410 of Set 2 | ribeira brava
# Processing Record 411 of Set 2 | del rio
# Processing Record 412 of Set 2 | tarragona
# Processing Record 413 of Set 2 | zhigansk
# Processing Record 414 of Set 2 | patterson
# Processing Record 415 of Set 2 | teguldet
# Processing Record 416 of Set 2 | beringovskiy
# Processing Record 417 of Set 2 | ponta do sol
# Info not found. Skipping...
# Processing Record 419 of Set 2 | phan thiet
# Processing Record 420 of Set 2 | asyut
# Processing Record 421 of Set 2 | baghdad
# Processing Record 422 of Set 2 | vinh long
# Processing Record 423 of Set 2 | ulladulla
# Processing Record 424 of Set 2 | lorengau
# Processing Record 425 of Set 2 | haines junction
# Processing Record 426 of Set 2 | lardos
# Processing Record 427 of Set 2 | talant
# Info not found. Skipping...
# Processing Record 429 of Set 2 | tres picos
# Processing Record 430 of Set 2 | kamina
# Processing Record 431 of Set 2 | bandarbeyla
# Processing Record 432 of Set 2 | hamilton
# Processing Record 433 of Set 2 | torbay
# Processing Record 434 of Set 2 | neiafu
# Processing Record 435 of Set 2 | vardo
# Processing Record 436 of Set 2 | alyangula
# Processing Record 437 of Set 2 | niamey
# Processing Record 438 of Set 2 | abha
# Processing Record 439 of Set 2 | shu
# Processing Record 440 of Set 2 | tura
# Processing Record 441 of Set 2 | saint-francois
# Processing Record 442 of Set 2 | yeppoon
# Processing Record 443 of Set 2 | eureka
# Processing Record 444 of Set 2 | kaeo
# Info not found. Skipping...
# Processing Record 446 of Set 2 | usuki
# Processing Record 447 of Set 2 | keti bandar
# Processing Record 448 of Set 2 | xapuri
# Processing Record 449 of Set 2 | port hedland
# Processing Record 450 of Set 2 | novodugino
# Processing Record 451 of Set 2 | srivardhan
# Processing Record 452 of Set 2 | cayenne
# Processing Record 453 of Set 2 | hambantota
# Processing Record 454 of Set 2 | umm lajj
# Processing Record 455 of Set 2 | moussoro
# Processing Record 456 of Set 2 | christchurch
# Processing Record 457 of Set 2 | soyo
# Processing Record 458 of Set 2 | lebanon
# Processing Record 459 of Set 2 | fuerte olimpo
# Processing Record 460 of Set 2 | aksha
# Processing Record 461 of Set 2 | fort nelson
# Processing Record 462 of Set 2 | harper
# Processing Record 463 of Set 2 | fairbanks
# Processing Record 464 of Set 2 | inongo
# Processing Record 465 of Set 2 | college
# Processing Record 466 of Set 2 | kemijarvi
# Processing Record 467 of Set 2 | palauig
# Processing Record 468 of Set 2 | hamadan
# Processing Record 469 of Set 2 | airai
# Processing Record 470 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 471 of Set 2 | ahipara
# Processing Record 472 of Set 2 | nome
# Processing Record 473 of Set 2 | pangai
# Processing Record 474 of Set 2 | maragogi
# Processing Record 475 of Set 2 | prince albert
# Processing Record 476 of Set 2 | ust-koksa
# Processing Record 477 of Set 2 | chimbote
# Processing Record 478 of Set 2 | dzhebariki-khaya
# Processing Record 479 of Set 2 | rolla
# Processing Record 480 of Set 2 | verkhnyaya inta
# Processing Record 481 of Set 2 | dzaoudzi
# Processing Record 482 of Set 2 | kushuhum
# Processing Record 483 of Set 2 | mahebourg
# Info not found. Skipping...
# Processing Record 485 of Set 2 | north bend
# Processing Record 486 of Set 2 | ilhabela
# Processing Record 487 of Set 2 | dawei
# Processing Record 488 of Set 2 | kendari
# Processing Record 489 of Set 2 | gat
# Processing Record 490 of Set 2 | ust-tsilma
# Processing Record 491 of Set 2 | puerto del rosario
# Processing Record 492 of Set 2 | eyrarbakki
# Processing Record 493 of Set 2 | anamur
# Processing Record 494 of Set 2 | tamahu
# Processing Record 495 of Set 2 | lasa
# Processing Record 496 of Set 2 | gilbues
# Processing Record 497 of Set 2 | vaitape
# Processing Record 498 of Set 2 | srednekolymsk
# Processing Record 499 of Set 2 | north adams
# Processing Record 500 of Set 2 | shingu
# Processing Record 501 of Set 2 | buala
# Processing Record 502 of Set 2 | thinadhoo
# Processing Record 503 of Set 2 | setaka
# Processing Record 504 of Set 2 | berlevag
# Processing Record 505 of Set 2 | yulara
# Processing Record 506 of Set 2 | rudbar
# Processing Record 507 of Set 2 | lososina
# Processing Record 508 of Set 2 | maceio
# Processing Record 509 of Set 2 | kilindoni
# Processing Record 510 of Set 2 | atasu
# Processing Record 511 of Set 2 | sioux lookout
# Processing Record 512 of Set 2 | sal rei
# Processing Record 513 of Set 2 | dhidhdhoo
# Processing Record 514 of Set 2 | jimeta
# Processing Record 515 of Set 2 | marinette
# Processing Record 516 of Set 2 | veraval
# Processing Record 517 of Set 2 | gazli
# Processing Record 518 of Set 2 | aykhal
# Processing Record 519 of Set 2 | zhezkazgan
# Processing Record 520 of Set 2 | luga
# Processing Record 521 of Set 2 | oranjemund
# Processing Record 522 of Set 2 | meiganga
# Processing Record 523 of Set 2 | surt
# Processing Record 524 of Set 2 | grass valley
# Processing Record 525 of Set 2 | hit
# Processing Record 526 of Set 2 | tomatlan
# Processing Record 527 of Set 2 | lazaro cardenas
# Processing Record 528 of Set 2 | kuusamo
# Processing Record 529 of Set 2 | vyazemskiy
# Processing Record 530 of Set 2 | milkovo
# Processing Record 531 of Set 2 | provideniya
# Info not found. Skipping...
# Processing Record 533 of Set 2 | nurota
# Processing Record 534 of Set 2 | biggar
# Processing Record 535 of Set 2 | takab
# Processing Record 536 of Set 2 | condado
# Processing Record 537 of Set 2 | linxia
# Processing Record 538 of Set 2 | broome
# Processing Record 539 of Set 2 | wasilla
# Processing Record 540 of Set 2 | tiksi
# Processing Record 541 of Set 2 | qui nhon
# Processing Record 542 of Set 2 | kirakira
# Processing Record 543 of Set 2 | kedrovyy
# Info not found. Skipping...
# Processing Record 545 of Set 2 | mackay
# Info not found. Skipping...
# Processing Record 547 of Set 2 | panjakent
# Processing Record 548 of Set 2 | baruun-urt
# Processing Record 549 of Set 2 | varca
# Processing Record 550 of Set 2 | hervey bay
# Processing Record 551 of Set 2 | pangkalanbuun
# Processing Record 552 of Set 2 | half moon bay
# Processing Record 553 of Set 2 | wajima
# Processing Record 554 of Set 2 | agapovka
# Processing Record 555 of Set 2 | kjollefjord
# Processing Record 556 of Set 2 | sarankhola
# Processing Record 557 of Set 2 | longyearbyen
# Processing Record 558 of Set 2 | abu samrah
# Processing Record 559 of Set 2 | kolosovka
# Processing Record 560 of Set 2 | namatanai
# Processing Record 561 of Set 2 | bud
# Info not found. Skipping...
# Processing Record 563 of Set 2 | sao domingos do maranhao
# Processing Record 564 of Set 2 | sanlucar la mayor
# Processing Record 565 of Set 2 | kidal
# Processing Record 566 of Set 2 | general roca
# Processing Record 567 of Set 2 | bugulma
# Processing Record 568 of Set 2 | baragua
# Processing Record 569 of Set 2 | palmer
# Processing Record 570 of Set 2 | clarence town
# Processing Record 571 of Set 2 | waipawa
# Processing Record 572 of Set 2 | naze
# Processing Record 573 of Set 2 | kahului
# Processing Record 574 of Set 2 | oussouye
# Processing Record 575 of Set 2 | sines
# Processing Record 576 of Set 2 | road town
# Processing Record 577 of Set 2 | skjervoy
# Processing Record 578 of Set 2 | roald
# Processing Record 579 of Set 2 | tabou
# Processing Record 580 of Set 2 | namibe
# Processing Record 581 of Set 2 | alexandria
# Processing Record 582 of Set 2 | miguel calmon
# Processing Record 583 of Set 2 | corinto
# Processing Record 584 of Set 2 | beloha
# Info not found. Skipping...
# Processing Record 586 of Set 2 | valparaiso
# Processing Record 587 of Set 2 | wundanyi
# Processing Record 588 of Set 2 | gronau
# Processing Record 589 of Set 2 | hebi
# Processing Record 590 of Set 2 | nuevo ideal
# Info not found. Skipping...
# Processing Record 592 of Set 2 | ambovombe
# Processing Record 593 of Set 2 | presidente medici
# Processing Record 594 of Set 2 | mus
# Processing Record 595 of Set 2 | dunedin
# Processing Record 596 of Set 2 | simpang
# Processing Record 597 of Set 2 | kathu
# Processing Record 598 of Set 2 | aldan
# Processing Record 599 of Set 2 | grand-lahou
# Processing Record 600 of Set 2 | chokwe
# Processing Record 601 of Set 2 | vila franca do campo
# Processing Record 602 of Set 2 | buchanan
# Processing Record 603 of Set 2 | tara
# Processing Record 604 of Set 2 | arlit
# Processing Record 605 of Set 2 | loandjili
# Processing Record 606 of Set 2 | muroto
# Processing Record 607 of Set 2 | leh
# Processing Record 608 of Set 2 | timiryazevskoye
# Processing Record 609 of Set 2 | beira
# Processing Record 610 of Set 2 | necochea
# Processing Record 611 of Set 2 | port-gentil
# Processing Record 612 of Set 2 | vikhorevka
# Processing Record 613 of Set 2 | itarema
# Info not found. Skipping...
# Processing Record 615 of Set 2 | inuvik
# Processing Record 616 of Set 2 | biak
# Processing Record 617 of Set 2 | puerto el triunfo
# Processing Record 618 of Set 2 | staszow
# Processing Record 619 of Set 2 | bonavista
# Processing Record 620 of Set 2 | eenhana
# Info not found. Skipping...
# Processing Record 622 of Set 2 | bubaque
# Processing Record 623 of Set 2 | wakefield
# Processing Record 624 of Set 2 | talaya
# Info not found. Skipping...
# Processing Record 626 of Set 2 | kieta
# Processing Record 627 of Set 2 | woodstock
# Processing Record 628 of Set 2 | itoman
# Processing Record 629 of Set 2 | fuyang
# Processing Record 630 of Set 2 | sungairaya
# Processing Record 631 of Set 2 | iracoubo
# Processing Record 632 of Set 2 | matay

# %%
data = {'City' : city_list, 'Country' : country, 
        'Lat' : latitudes, 'Lng' : longitudes,
        'Max Temp' : temp, 'Humidity' : humidity, 
        'Cloudiness' : clouds, 'Wind Speed' : wind}

weather_df = pd.DataFrame(data)

weather_df.head()
weather_df.to_csv('../Output_Data/Weather_Data.csv')
# Out:
#   Country    Lat    Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0      GL  77.48  77.48    -22.59        54           0        4.74
# 1      AR -54.80 -54.80     46.40        87          90        5.82
# 2      CA  50.23  50.23     17.60        67          90        8.05
# 3      AR -38.00 -38.00     73.99        77          90       12.75
# 4      BR -24.79 -24.79     83.35        31           0        2.98

# %%
plt.scatter(latitudes, temp)
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title('Temperature by Latitude')
plt.grid(True)
plt.savefig('../Output_Data/lat_temp.png')

# %%
plt.scatter(latitudes, humidity)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Humidity by Latitude')
plt.grid(True)
plt.savefig('../Output_Data/lat_humidity.png')

# %%
plt.scatter(latitudes, clouds)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Cloudiness by Latitude')
plt.grid(True)
plt.savefig('../Output_Data/lat_cloud.png')

# %%
plt.scatter(latitudes, wind)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.title('Wind Speed by Latitude')
plt.grid(True)
plt.savefig('../Output_Data/wind.png')

# %% [markdown]
# # Linear Regression
#
# Create Northern and Southern Hemisphere DataFrames

# %%
# A function to create linear regression plots
def regress(x, y, hemisphere):
    hem = []
    i = []
    
    # Checks for hemisphere argument ('n' or 's')
    if hemisphere == 'n':
        
        # For every latitude, check if greater than or equal to 0
        for lat in x:
            if lat >= 0:
                
                # Adds values to lists if meets requirement
                hem.append(lat)
                i.append(y[x.index(lat)]) 
                
        coords = (0,10)
    
    # Same, but for the Southern Hemisphere
    if hemisphere == 's':
        for lat in x:
            if lat <= 0:
                hem.append(lat)
                i.append(y[x.index(lat)])

        coords = (-50,20)

                
    # Calculates linear regression
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(hem,i)
    hem = np.asarray(hem, dtype=np.float64)
    regress_values = hem * slope + intercept

    # Plots scatter plot and regresion
    plt.scatter(hem,i)
    plt.plot(hem,regress_values,"r-")

    # Annotates graph with equation
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.annotate(line_eq,xy=coords,fontsize=15,color="red")
    plt.xlabel('Latitude')
    
    # Prints r squared value from linregress function
    print(f'The r-squared is: {rvalue}')

# %%
regress(latitudes,temp,'n')
plt.ylabel('Temp (F)')
plt.title('Temp in the Northern Hemisphere')
# Out:
# The r-squared is: -0.8512682897699227

# %%
regress(latitudes,temp,'s')
plt.ylim(20,110)
plt.ylabel('Temp (F)')
plt.title('Temp in the Southern Hemisphere')
# Out:
# The r-squared is: 0.5787945892580787
# (20, 110)

# %%
regress(latitudes, humidity, 'n')
plt.ylabel('Humidity (%)')
plt.title('Humidity in the Northern Hemisphere')
# Out:
# The r-squared is: 0.31689641751742564

# %%
regress(latitudes, humidity, 's')
plt.ylabel('Humidity (%)')
plt.title('Humidity in the Southern Hemisphere')
# Out:
# The r-squared is: 0.10700781275535895

# %%
regress(latitudes, clouds , 'n')
plt.ylabel('Cloudiness (%)')
plt.title('Clouldines in the Northern Hemisphere')
# Out:
# The r-squared is: 0.21756741295660487

# %%
regress(latitudes, clouds , 's')
plt.ylabel('Cloudiness (%)')
plt.title('Cloudiness in the Southern Hemisphere')
# Out:
# The r-squared is: 0.1449680828292557

# %%
regress(latitudes, wind ,'n')
plt.ylabel('Wind Speed (MPH)')
plt.title('Wind speed in the Northern Hemisphere')
# Out:
# The r-squared is: 0.19186295758885955

# %%
regress(latitudes, wind ,'s')
plt.ylabel('Wind Speed (MPH)')
plt.title('Wind speed in the Southern Hemisphere')
# Out:
# The r-squared is: -0.21762856195433994
